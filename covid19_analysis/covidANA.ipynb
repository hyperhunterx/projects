# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("covid19_Confirmed_dataset.csv")
df1.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
df1.shape
# Out:
# (266, 104)

# %%
# df1.drop(["Province/State"],axis=1,inplace=True)
df1.drop(["Lat","Long"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17736\2943100057.py in <module>
#       1 # df1.drop(["Province/State"],axis=1,inplace=True)
# ----> 2 df1.drop(["Lat","Long"],axis=1,inplace=True)
#
# c:\Users\Shweta Jain\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Shweta Jain\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df1
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN         Western Sahara        0        0        0        0
# 262            NaN  Sao Tome and Principe        0        0        0        0
# 263            NaN                  Yemen        0        0        0        0
# 264            NaN                Comoros        0        0        0        0
# 265            NaN             Tajikistan        0        0        0        0
#
# ...

# %%
df1.shape
# Out:
# (266, 102)

# %%
covid_df = df1.groupby("Country/Region").sum()

# %%
covid_df.tail(20)
# Out:
#                       1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Thailand                    2        3        5        7        8        8
# Timor-Leste                 0        0        0        0        0        0
# Togo                        0        0        0        0        0        0
# Trinidad and Tobago         0        0        0        0        0        0
# Tunisia                     0        0        0        0        0        0
# Turkey                      0        0        0        0        0        0
# US                          1        1        2        2        5        5
# Uganda                      0        0        0        0        0        0
# Ukraine                     0        0        0        0        0        0
# United Arab Emirates        0        0        0        0        0        0
# United Kingdom              0        0        0        0        0        0
# ...

# %%
covid_df.loc["China"].plot()
covid_df.loc["Spain"].plot()
covid_df.loc["Italy"].plot()
covid_df.loc["India"].plot()
plt.legend()

# %%
covid_df.loc["China"].plot()
# Out:
# <AxesSubplot:>
